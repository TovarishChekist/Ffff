# %% [markdown]
# # 🤖 Telegram-бот Детского и Молодёжного Совета
#
# ## ⚠️ ВАЖНО: Ограничения Google Colab
#
# - ❌ Сессия закрывается через **12 часов** максимум
# - ❌ Закрывается при **90 минутах неактивности**
# - ❌ Нет гарантии доступности 24/7
#
# **Используйте только для тестирования!**
#
# Для постоянной работы используйте [PythonAnywhere](https://github.com/TovarishChekist/Ffff/blob/claude/rewrite-telegram-bot-EEBhi/DEPLOYMENT_PYTHONANYWHERE.md)
#
# ---
#
# ## 📋 Инструкция
#
# 1. Выполните все ячейки по порядку
# 2. В ячейке 3 замените данные на свои
# 3. Бот будет работать пока открыт блокнот
# 4. Остановить: `Runtime → Interrupt execution`

# %% [markdown]
# ## 1️⃣ Клонирование репозитория

# %%
# Клонируем репозиторий
print("📦 Клонирование репозитория...")
# !git clone -q https://github.com/TovarishChekist/Ffff.git
# %cd Ffff
# !git checkout -q claude/rewrite-telegram-bot-EEBhi
print("✅ Репозиторий клонирован")

# %% [markdown]
# ## 2️⃣ Установка зависимостей

# %%
# Устанавливаем зависимости для бота
print("📦 Установка зависимостей...")
# !pip install -q -r requirements-bot.txt
print("✅ Зависимости установлены")

# %% [markdown]
# ## 3️⃣ Конфигурация бота
#
# ### ⚠️ ВАЖНО: Замените значения на свои!
#
# Как получить данные:
# - **BOT_TOKEN** - получите у [@BotFather](https://t.me/BotFather)
# - **APPEAL_CHAT_ID** / **APPLICATION_CHAT_ID** - добавьте [@userinfobot](https://t.me/userinfobot) в группу
# - **ADMIN_IDS** - ваш Telegram ID от [@userinfobot](https://t.me/userinfobot)

# %%
import os

# ==========================================
# 🔧 ЗАМЕНИТЕ ЭТИ ЗНАЧЕНИЯ НА СВОИ!
# ==========================================

BOT_TOKEN = "7710087256:AAFWHXIhrIkwL2pMLuhrvtIo8BvFCk7CebA"  # Ваш токен от @BotFather
APPEAL_CHAT_ID = "-1002863620257"                              # ID чата для обращений
APPLICATION_CHAT_ID = "-1002692926810"                         # ID чата для заявок
ADMIN_IDS = "123456789"                                        # Ваш Telegram ID (через запятую если несколько)

# ==========================================

# Устанавливаем переменные окружения
os.environ['TELEGRAM_BOT_TOKEN'] = BOT_TOKEN
os.environ['APPEAL_CHAT_ID'] = APPEAL_CHAT_ID
os.environ['APPLICATION_CHAT_ID'] = APPLICATION_CHAT_ID
os.environ['ADMIN_IDS'] = ADMIN_IDS
os.environ['LOG_LEVEL'] = 'INFO'
os.environ['CONNECT_TIMEOUT'] = '15.0'
os.environ['READ_TIMEOUT'] = '15.0'

print("✅ Конфигурация установлена")
print(f"📱 Bot Token: {BOT_TOKEN[:20]}...")
print(f"💬 Appeal Chat: {APPEAL_CHAT_ID}")
print(f"📝 Application Chat: {APPLICATION_CHAT_ID}")
print(f"👤 Admin IDs: {ADMIN_IDS}")

# %% [markdown]
# ## 4️⃣ Запуск бота
#
# ### ℹ️ Информация:
# - Бот будет работать пока выполняется эта ячейка
# - Вы увидите логи работы бота
# - Чтобы остановить: `Runtime → Interrupt execution` или кнопка ⏹️
# - Проверьте бота в Telegram: отправьте `/start`

# %%
print("="*60)
print("🚀 ЗАПУСК БОТА")
print("="*60)
print("\n⚠️ Важно:")
print("- Бот работает пока открыт блокнот")
print("- Максимум 12 часов")
print("- Остановить: Runtime → Interrupt execution")
print("- Проверить: откройте бота в Telegram и отправьте /start")
print("\n" + "="*60 + "\n")

# !python run_bot.py

# %% [markdown]
# ## 📊 Дополнительные команды (опционально)

# %%
# Просмотр последних логов
# !tail -n 50 bot.log

# %%
# Проверка статуса бота
# !ps aux | grep run_bot.py

# %%
# Остановка бота (если запущен в фоне)
# !pkill -f run_bot.py
print("✅ Бот остановлен")

# %% [markdown]
# ---
#
# ## 🔗 Полезные ссылки
#
# - [Документация по боту](https://github.com/TovarishChekist/Ffff/blob/claude/rewrite-telegram-bot-EEBhi/telegram_bot/README.md)
# - [PythonAnywhere (постоянный хостинг)](https://github.com/TovarishChekist/Ffff/blob/claude/rewrite-telegram-bot-EEBhi/DEPLOYMENT_PYTHONANYWHERE.md)
# - [Быстрый старт](https://github.com/TovarishChekist/Ffff/blob/claude/rewrite-telegram-bot-EEBhi/QUICKSTART.md)
# - [История изменений](https://github.com/TovarishChekist/Ffff/blob/claude/rewrite-telegram-bot-EEBhi/CHANGELOG_BOT.md)
#
# ## 💡 Помощь
#
# - [@BotFather](https://t.me/BotFather) - создание бота и получение токена
# - [@userinfobot](https://t.me/userinfobot) - узнать свой Telegram ID
#
# ---
#
# **Версия:** 2.1.0 | **Автор:** Детский и Молодёжный Общественный Совет
